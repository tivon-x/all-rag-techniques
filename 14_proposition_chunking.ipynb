# %% [markdown]
# <a href="https://colab.research.google.com/github/tivon-x/all-rag-techniques/blob/main/14_proposition_chunking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 提出命题分块以增强 RAG
#
# 在这个笔记本中，我实现了命题分块——这是一种高级技术，用于将文档分解为原子级的事实陈述，以实现更准确的检索。与传统的按字符计数简单分割文本的分块方式不同，命题分块保留了各个事实的语义完整性。
#
# 命题分块通过以下方式实现更精确的检索：
#
# 1. 将内容分解为原子性、事实性、自包含性和简洁性的事实
# 2. 创建更小、更细粒度的检索单元
# 3. 实现查询与相关内容之间的更精确匹配
# 4. 过滤掉低质量或不完整的命题
#
# 关键部件。
#
# 1. **命题生成：**使用LLM将文档块分解为事实性的、自包含的命题。
# 2. **命题质量检查：**根据准确性、清晰度、完整性和简洁性评估生成的命题。
#
# 命题分块方法的动机是构建一个系统，将文本文件分解为简洁、事实性的命题，以便进行更细粒度和更精确的信息检索。使用命题可以实现更精细的控制，并更好地处理特定查询，尤其是在从详细或复杂的文本中提取知识时。比较使用较小的命题分块和较大的文档分块，旨在评估细粒度信息检索的有效性。
#
# 好处：
# - **细粒度性：**通过将文档分解为小的事实性命题，系统能够实现高度具体的检索，从而更容易从大型或复杂的文档中提取精确答案。
# - **质量保证：** 使用质量检查的大语言模型确保生成的命题符合特定标准，从而提高检索信息的可靠性。
# - **检索灵活性：** 对比基于命题的检索和基于较大块的检索，可以评估在搜索结果中细粒度与更广泛上下文之间的权衡。

# %% [markdown]
# <img src="https://github.com/tivon-x/all-rag-techniques/blob/main/images/proposition_chunking.svg?raw=1" alt="Reliable-RAG" width="600">

# %% [markdown]
# ## 环境设置

# %%
# fitz库需要从pymudf那里安装
# %pip install --quiet --force-reinstall pymupdf
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 55.6 MB/s eta 0:00:00

# %%
import os
import numpy as np
import json
import fitz
from openai import OpenAI
import re

# %% [markdown]
# ## 提取文本

# %%
def extract_text_from_pdf(pdf_path):
    """
    Extracts text from a PDF file and prints the first `num_chars` characters.

    Args:
    pdf_path (str): Path to the PDF file.

    Returns:
    str: Extracted text from the PDF.
    """
    # Open the PDF file
    mypdf = fitz.open(pdf_path)
    all_text = ""  # Initialize an empty string to store the extracted text

    # Iterate through each page in the PDF
    for page_num in range(mypdf.page_count):
        page = mypdf[page_num]  # Get the page
        text = page.get_text("text")  # Extract text from the page
        all_text += text  # Append the extracted text to the all_text string

    return all_text  # Return the extracted text

# %% [markdown]
# ## 分块

# %%
def chunk_text(text, chunk_size=800, overlap=100):
    """
    Split text into overlapping chunks.

    Args:
        text (str): Input text to chunk
        chunk_size (int): Size of each chunk in characters
        overlap (int): Overlap between chunks in characters

    Returns:
        List[Dict]: List of chunk dictionaries with text and metadata
    """
    chunks = []  # Initialize an empty list to store the chunks

    # Iterate over the text with the specified chunk size and overlap
    for i in range(0, len(text), chunk_size - overlap):
        chunk = text[i:i + chunk_size]  # Extract a chunk of the specified size
        if chunk:  # Ensure we don't add empty chunks
            chunks.append({
                "text": chunk,  # The chunk text
                "chunk_id": len(chunks) + 1,  # Unique ID for the chunk
                "start_char": i,  # Starting character index of the chunk
                "end_char": i + len(chunk)  # Ending character index of the chunk
            })

    print(f"Created {len(chunks)} text chunks")  # Print the number of created chunks
    return chunks  # Return the list of chunks

# %% [markdown]
# ## OpenAI API Client

# %%
# colab环境
from google.colab import userdata
# 使用火山引擎
api_key = userdata.get("ARK_API_KEY")
base_url = userdata.get("ARK_BASE_URL")

# %%
model_name = "doubao-1-5-lite-32k-250115"
embedding_model = "doubao-embedding-text-240715"

# %%
client = OpenAI(
    base_url=base_url,
    api_key=api_key
)

# %% [markdown]
# ## 向量数据库

# %%
class SimpleVectorStore:
    """
    A simple vector store implementation using NumPy.
    """
    def __init__(self):
        # Initialize lists to store vectors, texts, and metadata
        self.vectors = []
        self.texts = []
        self.metadata = []

    def add_item(self, text, embedding, metadata=None):
        """
        Add an item to the vector store.

        Args:
            text (str): The text content
            embedding (List[float]): The embedding vector
            metadata (Dict, optional): Additional metadata
        """
        # Append the embedding, text, and metadata to their respective lists
        self.vectors.append(np.array(embedding))
        self.texts.append(text)
        self.metadata.append(metadata or {})

    def add_items(self, texts, embeddings, metadata_list=None):
        """
        Add multiple items to the vector store.

        Args:
            texts (List[str]): List of text contents
            embeddings (List[List[float]]): List of embedding vectors
            metadata_list (List[Dict], optional): List of metadata dictionaries
        """
        # If no metadata list is provided, create an empty dictionary for each text
        if metadata_list is None:
            metadata_list = [{} for _ in range(len(texts))]

        # Add each text, embedding, and metadata to the store
        for text, embedding, metadata in zip(texts, embeddings, metadata_list):
            self.add_item(text, embedding, metadata)

    def similarity_search(self, query_embedding, k=5):
        """
        Find the most similar items to a query embedding.

        Args:
            query_embedding (List[float]): Query embedding vector
            k (int): Number of results to return

        Returns:
            List[Dict]: Top k most similar items
        """
        # Return an empty list if there are no vectors in the store
        if not self.vectors:
            return []

        # Convert query embedding to a numpy array
        query_vector = np.array(query_embedding)

        # Calculate similarities using cosine similarity
        similarities = []
        for i, vector in enumerate(self.vectors):
            similarity = np.dot(query_vector, vector) / (np.linalg.norm(query_vector) * np.linalg.norm(vector))
            similarities.append((i, similarity))

        # Sort by similarity in descending order
        similarities.sort(key=lambda x: x[1], reverse=True)

        # Collect the top k results
        results = []
        for i in range(min(k, len(similarities))):
            idx, score = similarities[i]
            results.append({
                "text": self.texts[idx],
                "metadata": self.metadata[idx],
                "similarity": float(score)  # Convert to float for JSON serialization
            })

        return results

# %% [markdown]
# ## 创建嵌入向量

# %%
def create_embeddings(text, model = None, batch_size = 10):
    """
    Creates embeddings for the given text.

    Args:
    text (str or List[str]): The input text(s) for which embeddings are to be created.
    model (str): The model to be used for creating embeddings.
    batch_size (int): batch size

    Returns:
    List[float] or List[List[float]]: The embedding vector(s).
    """
    if not model:
      model = embedding_model

    # Convert single string to list for uniform processing
    input_text = text if isinstance(text, list) else [text]

    all_embeddings = []

    for i in range(0, len(input_text), batch_size):
      batch = input_text[i : i + batch_size]
      # Create embeddings for the batch using the specified model
      response = client.embeddings.create(
          model=model,
          input=batch
      )
      all_embeddings.extend(item.embedding for item in response.data)

    return all_embeddings if isinstance(text, list) else all_embeddings[0]

# %% [markdown]
# ## 命题生成

# %%
def generate_propositions(chunk):
    """
    从文本块中生成原子级的、自包含的命题。

    Args:
        chunk (Dict): Text chunk with content and metadata

    Returns:
        List[str]: List of generated propositions
    """
    # System prompt to instruct the AI on how to generate propositions
    system_prompt = """Please break down the following text into simple, self-contained propositions.
    Ensure that each proposition meets the following criteria:

    1. Express a Single Fact: Each proposition should state one specific fact or claim.
    2. Be Understandable Without Context: The proposition should be self-contained, meaning it can be understood without needing additional context.
    3. Use Full Names, Not Pronouns: Avoid pronouns or ambiguous references; use full entity names.
    4. Include Relevant Dates/Qualifiers: If applicable, include necessary dates, times, and qualifiers to make the fact precise.
    5. Contain One Subject-Predicate Relationship: Focus on a single subject and its corresponding action or attribute, without conjunctions or multiple clauses.

    Output ONLY the list of propositions without any additional text or explanations."""

    # User prompt containing the text chunk to be converted into propositions
    user_prompt = f"Text to convert into propositions:\n\n{chunk['text']}"

    # Generate response from the model
    response = client.chat.completions.create(
        model=model_name,  # Using a stronger model for accurate proposition generation
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        temperature=0
    )

    # Extract propositions from the response
    raw_propositions = response.choices[0].message.content.strip().split('\n')

    # Clean up propositions (remove numbering, bullets, etc.)
    clean_propositions = []
    for prop in raw_propositions:
        # Remove numbering (1., 2., etc.) and bullet points
        cleaned = re.sub(r'^\s*(\d+\.|\-|\*)\s*', '', prop).strip()
        if cleaned and len(cleaned) > 10:  # Simple filter for empty or very short propositions
            clean_propositions.append(cleaned)

    return clean_propositions

# %% [markdown]
# ## 命题质量检测

# %%
def evaluate_proposition(proposition, original_text):
    """
    根据准确性、清晰性、完整性和简洁性评估命题的质量。

    Args:
        proposition (str): The proposition to evaluate
        original_text (str): The original text for comparison

    Returns:
        Dict: Scores for each evaluation dimension
    """
    # System prompt to instruct the AI on how to evaluate the proposition
    system_prompt = """You are an expert at evaluating the quality of propositions extracted from text.
    Rate the given proposition on the following criteria (scale 1-10):

    - Accuracy: How well the proposition reflects information in the original text
    - Clarity: How easy it is to understand the proposition without additional context
    - Completeness: Whether the proposition includes necessary details (dates, qualifiers, etc.)
    - Conciseness: Whether the proposition is concise without losing important information

    The response must be in valid JSON format with numerical scores for each criterion:
    {"accuracy": X, "clarity": X, "completeness": X, "conciseness": X}
    """

    # User prompt containing the proposition and the original text
    user_prompt = f"""Proposition: {proposition}

    Original Text: {original_text}

    Please provide your evaluation scores in JSON format."""

    # Generate response from the model
    response = client.chat.completions.create(
        model=model_name,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        response_format={"type": "json_object"},
        temperature=0
    )

    # Parse the JSON response
    try:
        scores = json.loads(response.choices[0].message.content.strip())
        return scores
    except json.JSONDecodeError:
        # Fallback if JSON parsing fails
        print("JSON generation ERROR!")
        return {
            "accuracy": 5,
            "clarity": 5,
            "completeness": 5,
            "conciseness": 5
        }

# %% [markdown]
# ## 命题处理流程

# %%
def process_document_into_propositions(pdf_path, chunk_size=800, chunk_overlap=100,
                                      quality_thresholds=None):
    """
    将文档处理成经过质量检查的命题。

    Args:
        pdf_path (str): Path to the PDF file
        chunk_size (int): Size of each chunk in characters
        chunk_overlap (int): Overlap between chunks in characters
        quality_thresholds (Dict): Threshold scores for proposition quality

    Returns:
        Tuple[List[Dict], List[Dict]]: Original chunks and proposition chunks
    """
    # Set default quality thresholds if not provided
    if quality_thresholds is None:
        quality_thresholds = {
            "accuracy": 7,
            "clarity": 7,
            "completeness": 7,
            "conciseness": 7
        }

    # Extract text from the PDF file
    text = extract_text_from_pdf(pdf_path)

    # Create chunks from the extracted text
    chunks = chunk_text(text, chunk_size, chunk_overlap)

    # Initialize a list to store all propositions
    all_propositions = []

    print("Generating propositions from chunks...")
    for i, chunk in enumerate(chunks):
        print(f"Processing chunk {i+1}/{len(chunks)}...")

        # Generate propositions for the current chunk
        chunk_propositions = generate_propositions(chunk)
        print(f"Generated {len(chunk_propositions)} propositions")

        # Process each generated proposition
        for prop in chunk_propositions:
            proposition_data = {
                "text": prop,
                "source_chunk_id": chunk["chunk_id"],
                "source_text": chunk["text"]
            }
            all_propositions.append(proposition_data)

    # Evaluate the quality of the generated propositions
    print("\nEvaluating proposition quality...")
    quality_propositions = []

    for i, prop in enumerate(all_propositions):
        if i % 10 == 0:  # Status update every 10 propositions
            print(f"Evaluating proposition {i+1}/{len(all_propositions)}...")

        # Evaluate the quality of the current proposition
        scores = evaluate_proposition(prop["text"], prop["source_text"])
        prop["quality_scores"] = scores

        # Check if the proposition passes the quality thresholds
        passes_quality = True
        for metric, threshold in quality_thresholds.items():
            if scores.get(metric, 0) < threshold:
                passes_quality = False
                break

        if passes_quality:
            quality_propositions.append(prop)
        else:
            print(f"Proposition failed quality check: {prop['text'][:50]}...")

    print(f"\nRetained {len(quality_propositions)}/{len(all_propositions)} propositions after quality filtering")

    return chunks, quality_propositions

# %% [markdown]
# ## 为文本块和命题构建向量数据库

# %%
def build_vector_stores(chunks, propositions):
    """
    Build vector stores for both chunk-based and proposition-based approaches.

    Args:
        chunks (List[Dict]): Original document chunks
        propositions (List[Dict]): Quality-filtered propositions

    Returns:
        Tuple[SimpleVectorStore, SimpleVectorStore]: Chunk and proposition vector stores
    """
    # Create vector store for chunks
    chunk_store = SimpleVectorStore()

    # Extract chunk texts and create embeddings
    chunk_texts = [chunk["text"] for chunk in chunks]
    print(f"Creating embeddings for {len(chunk_texts)} chunks...")
    chunk_embeddings = create_embeddings(chunk_texts)

    # Add chunks to vector store with metadata
    chunk_metadata = [{"chunk_id": chunk["chunk_id"], "type": "chunk"} for chunk in chunks]
    chunk_store.add_items(chunk_texts, chunk_embeddings, chunk_metadata)

    # Create vector store for propositions
    prop_store = SimpleVectorStore()

    # Extract proposition texts and create embeddings
    prop_texts = [prop["text"] for prop in propositions]
    print(f"Creating embeddings for {len(prop_texts)} propositions...")
    prop_embeddings = create_embeddings(prop_texts)

    # Add propositions to vector store with metadata
    prop_metadata = [
        {
            "type": "proposition",
            "source_chunk_id": prop["source_chunk_id"],
            "quality_scores": prop["quality_scores"]
        }
        for prop in propositions
    ]
    prop_store.add_items(prop_texts, prop_embeddings, prop_metadata)

    return chunk_store, prop_store

# %% [markdown]
# ## 查询与检索函数

# %%
def retrieve_from_store(query, vector_store, k=5):
    """
    Retrieve relevant items from a vector store based on query.

    Args:
        query (str): User query
        vector_store (SimpleVectorStore): Vector store to search
        k (int): Number of results to retrieve

    Returns:
        List[Dict]: Retrieved items with scores and metadata
    """
    # Create query embedding
    query_embedding = create_embeddings(query)

    # Search vector store for the top k most similar items
    results = vector_store.similarity_search(query_embedding, k=k)

    return results

# %%
def compare_retrieval_approaches(query, chunk_store, prop_store, k=5):
    """
    Compare chunk-based and proposition-based retrieval for a query.

    Args:
        query (str): User query
        chunk_store (SimpleVectorStore): Chunk-based vector store
        prop_store (SimpleVectorStore): Proposition-based vector store
        k (int): Number of results to retrieve from each store

    Returns:
        Dict: Comparison results
    """
    print(f"\n=== Query: {query} ===")

    # Retrieve results from the proposition-based vector store
    print("\nRetrieving with proposition-based approach...")
    prop_results = retrieve_from_store(query, prop_store, k)

    # Retrieve results from the chunk-based vector store
    print("Retrieving with chunk-based approach...")
    chunk_results = retrieve_from_store(query, chunk_store, k)

    # Display proposition-based results
    print("\n=== Proposition-Based Results ===")
    for i, result in enumerate(prop_results):
        print(f"{i+1}) {result['text']} (Score: {result['similarity']:.4f})")

    # Display chunk-based results
    print("\n=== Chunk-Based Results ===")
    for i, result in enumerate(chunk_results):
        # Truncate text to keep the output manageable
        truncated_text = result['text'][:150] + "..." if len(result['text']) > 150 else result['text']
        print(f"{i+1}) {truncated_text} (Score: {result['similarity']:.4f})")

    # Return the comparison results
    return {
        "query": query,
        "proposition_results": prop_results,
        "chunk_results": chunk_results
    }

# %% [markdown]
# ## 响应生成与评估

# %%
def generate_response(query, results, result_type="proposition"):
    """
    Generate a response based on retrieved results.

    Args:
        query (str): User query
        results (List[Dict]): Retrieved items
        result_type (str): Type of results ('proposition' or 'chunk')

    Returns:
        str: Generated response
    """
    # Combine retrieved texts into a single context string
    context = "\n\n".join([result["text"] for result in results])

    # System prompt to instruct the AI on how to generate the response
    system_prompt = f"""You are an AI assistant answering questions based on retrieved information.
Your answer should be based on the following {result_type}s that were retrieved from a knowledge base.
If the retrieved information doesn't answer the question, acknowledge this limitation."""

    # User prompt containing the query and the retrieved context
    user_prompt = f"""Query: {query}

Retrieved {result_type}s:
{context}

Please answer the query based on the retrieved information."""

    # Generate the response using the OpenAI client
    response = client.chat.completions.create(
        model=model_name,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        temperature=0.2
    )

    # Return the generated response text
    return response.choices[0].message.content

# %%
def evaluate_responses(query, prop_response, chunk_response, reference_answer=None):
    """
    Evaluate and compare responses from both approaches.

    Args:
        query (str): User query
        prop_response (str): Response from proposition-based approach
        chunk_response (str): Response from chunk-based approach
        reference_answer (str, optional): Reference answer for comparison

    Returns:
        str: Evaluation analysis
    """
    # System prompt to instruct the AI on how to evaluate the responses
    system_prompt = """You are an expert evaluator of information retrieval systems.
    Compare the two responses to the same query, one generated from proposition-based retrieval
    and the other from chunk-based retrieval.

    Evaluate them based on:
    1. Accuracy: Which response provides more factually correct information?
    2. Relevance: Which response better addresses the specific query?
    3. Conciseness: Which response is more concise while maintaining completeness?
    4. Clarity: Which response is easier to understand?

    Be specific about the strengths and weaknesses of each approach."""

    # User prompt containing the query and the responses to be compared
    user_prompt = f"""Query: {query}

    Response from Proposition-Based Retrieval:
    {prop_response}

    Response from Chunk-Based Retrieval:
    {chunk_response}"""

    # If a reference answer is provided, include it in the user prompt for factual checking
    if reference_answer:
        user_prompt += f"""

    Reference Answer (for factual checking):
    {reference_answer}"""

    # Add the final instruction to the user prompt
    user_prompt += """
    Please provide a detailed comparison of these two responses, highlighting which approach performed better and why."""

    # Generate the evaluation analysis using the OpenAI client
    response = client.chat.completions.create(
        model=model_name,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        temperature=0
    )

    # Return the generated evaluation analysis
    return response.choices[0].message.content

# %% [markdown]
# ## 端到到评估流程

# %%
def run_proposition_chunking_evaluation(pdf_path, test_queries, reference_answers=None):
    """
    Run a complete evaluation of proposition chunking vs standard chunking.

    Args:
        pdf_path (str): Path to the PDF file
        test_queries (List[str]): List of test queries
        reference_answers (List[str], optional): Reference answers for queries

    Returns:
        Dict: Evaluation results
    """
    print("=== Starting Proposition Chunking Evaluation ===\n")

    # Process document into propositions and chunks
    chunks, propositions = process_document_into_propositions(pdf_path)

    # Build vector stores for chunks and propositions
    chunk_store, prop_store = build_vector_stores(chunks, propositions)

    # Initialize a list to store results for each query
    results = []

    # Run tests for each query
    for i, query in enumerate(test_queries):
        print(f"\n\n=== Testing Query {i+1}/{len(test_queries)} ===")
        print(f"Query: {query}")

        # Get retrieval results from both chunk-based and proposition-based approaches
        retrieval_results = compare_retrieval_approaches(query, chunk_store, prop_store)

        # Generate responses based on the retrieved proposition-based results
        print("\nGenerating response from proposition-based results...")
        prop_response = generate_response(
            query,
            retrieval_results["proposition_results"],
            "proposition"
        )

        # Generate responses based on the retrieved chunk-based results
        print("Generating response from chunk-based results...")
        chunk_response = generate_response(
            query,
            retrieval_results["chunk_results"],
            "chunk"
        )

        # Get reference answer if available
        reference = None
        if reference_answers and i < len(reference_answers):
            reference = reference_answers[i]

        # Evaluate the generated responses
        print("\nEvaluating responses...")
        evaluation = evaluate_responses(query, prop_response, chunk_response, reference)

        # Compile results for the current query
        query_result = {
            "query": query,
            "proposition_results": retrieval_results["proposition_results"],
            "chunk_results": retrieval_results["chunk_results"],
            "proposition_response": prop_response,
            "chunk_response": chunk_response,
            "reference_answer": reference,
            "evaluation": evaluation
        }

        # Append the results to the overall results list
        results.append(query_result)

        # Print the responses and evaluation for the current query
        print("\n=== Proposition-Based Response ===")
        print(prop_response)

        print("\n=== Chunk-Based Response ===")
        print(chunk_response)

        print("\n=== Evaluation ===")
        print(evaluation)

    # Generate overall analysis of the evaluation
    print("\n\n=== Generating Overall Analysis ===")
    overall_analysis = generate_overall_analysis(results)
    print("\n" + overall_analysis)

    # Return the evaluation results, overall analysis, and counts of propositions and chunks
    return {
        "results": results,
        "overall_analysis": overall_analysis,
        "proposition_count": len(propositions),
        "chunk_count": len(chunks)
    }

# %%
def generate_overall_analysis(results):
    """
    Generate an overall analysis of proposition vs chunk approaches.

    Args:
        results (List[Dict]): Results from each test query

    Returns:
        str: Overall analysis
    """
    # System prompt to instruct the AI on how to generate the overall analysis
    system_prompt = """You are an expert at evaluating information retrieval systems.
    Based on multiple test queries, provide an overall analysis comparing proposition-based retrieval
    to chunk-based retrieval for RAG (Retrieval-Augmented Generation) systems.

    Focus on:
    1. When proposition-based retrieval performs better
    2. When chunk-based retrieval performs better
    3. The overall strengths and weaknesses of each approach
    4. Recommendations for when to use each approach"""

    # Create a summary of evaluations for each query
    evaluations_summary = ""
    for i, result in enumerate(results):
        evaluations_summary += f"Query {i+1}: {result['query']}\n"
        evaluations_summary += f"Evaluation Summary: {result['evaluation'][:200]}...\n\n"

    # User prompt containing the summary of evaluations
    user_prompt = f"""Based on the following evaluations of proposition-based vs chunk-based retrieval across {len(results)} queries,
    provide an overall analysis comparing these two approaches:

    {evaluations_summary}

    Please provide a comprehensive analysis on the relative strengths and weaknesses of proposition-based
    and chunk-based retrieval for RAG systems."""

    # Generate the overall analysis using the OpenAI client
    response = client.chat.completions.create(
        model=model_name,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        temperature=0
    )

    # Return the generated analysis text
    return response.choices[0].message.content

# %% [markdown]
# ## Evaluation of Proposition Chunking

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Path to the AI information document that will be processed
pdf_path = "./drive/MyDrive/colab_data/AI_Information.pdf"

# Define test queries covering different aspects of AI to evaluate proposition chunking
test_queries = [
    "What are the main ethical concerns in AI development?",
    # "How does explainable AI improve trust in AI systems?",
    # "What are the key challenges in developing fair AI systems?",
    # "What role does human oversight play in AI safety?"
]

# Reference answers for more thorough evaluation and comparison of results
# These provide a ground truth to measure the quality of generated responses
reference_answers = [
    "The main ethical concerns in AI development include bias and fairness, privacy, transparency, accountability, safety, and the potential for misuse or harmful applications.",
    # "Explainable AI improves trust by making AI decision-making processes transparent and understandable to users, helping them verify fairness, identify potential biases, and better understand AI limitations.",
    # "Key challenges in developing fair AI systems include addressing data bias, ensuring diverse representation in training data, creating transparent algorithms, defining fairness across different contexts, and balancing competing fairness criteria.",
    # "Human oversight plays a critical role in AI safety by monitoring system behavior, verifying outputs, intervening when necessary, setting ethical boundaries, and ensuring AI systems remain aligned with human values and intentions throughout their operation."
]

# Run the evaluation
evaluation_results = run_proposition_chunking_evaluation(
    pdf_path=pdf_path,
    test_queries=test_queries,
    reference_answers=reference_answers
)

# Print the overall analysis
print("\n\n=== Overall Analysis ===")
print(evaluation_results["overall_analysis"])
# Out:
# === Starting Proposition Chunking Evaluation ===
#
# Created 48 text chunks
# Generating propositions from chunks...
# Processing chunk 1/48...
# Generated 4 propositions
# Processing chunk 2/48...
# Generated 13 propositions
# Processing chunk 3/48...
# Generated 10 propositions
# Processing chunk 4/48...
# Generated 14 propositions
# Processing chunk 5/48...
# Generated 9 propositions
# Processing chunk 6/48...
# Generated 7 propositions
# Processing chunk 7/48...
# Generated 18 propositions
# Processing chunk 8/48...
# Generated 21 propositions
# Processing chunk 9/48...
# Generated 6 propositions
# Processing chunk 10/48...
# Generated 6 propositions
# Processing chunk 11/48...
# Generated 7 propositions
# Processing chunk 12/48...
# Generated 7 propositions
# Processing chunk 13/48...
# Generated 6 propositions
# Processing chunk 14/48...
# Generated 7 propositions
# Processing chunk 15/48...
# Generated 10 propositions
# Processing chunk 16/48...
# Generated 17 propositions
# Processing chunk 17/48...
# Generated 6 propositions
# Processing chunk 18/48...
# Generated 6 propositions
# Processing chunk 19/48...
# Generated 8 propositions
# Processing chunk 20/48...
# Generated 20 propositions
# Processing chunk 21/48...
# Generated 13 propositions
# Processing chunk 22/48...
# Generated 7 propositions
# Processing chunk 23/48...
# Generated 11 propositions
# Processing chunk 24/48...
# Generated 7 propositions
# Processing chunk 25/48...
# Generated 5 propositions
# Processing chunk 26/48...
# Generated 19 propositions
# Processing chunk 27/48...
# Generated 5 propositions
# Processing chunk 28/48...
# Generated 18 propositions
# Processing chunk 29/48...
# Generated 7 propositions
# Processing chunk 30/48...
# Generated 10 propositions
# Processing chunk 31/48...
# Generated 17 propositions
# Processing chunk 32/48...
# Generated 6 propositions
# Processing chunk 33/48...
# Generated 18 propositions
# Processing chunk 34/48...
# Generated 13 propositions
# Processing chunk 35/48...
# Generated 12 propositions
# Processing chunk 36/48...
# Generated 18 propositions
# Processing chunk 37/48...
# Generated 10 propositions
# Processing chunk 38/48...
# Generated 5 propositions
# Processing chunk 39/48...
# Generated 17 propositions
# Processing chunk 40/48...
# Generated 10 propositions
# Processing chunk 41/48...
# Generated 6 propositions
# Processing chunk 42/48...
# Generated 22 propositions
# Processing chunk 43/48...
# Generated 10 propositions
# Processing chunk 44/48...
# Generated 7 propositions
# Processing chunk 45/48...
# Generated 6 propositions
# Processing chunk 46/48...
# Generated 15 propositions
# Processing chunk 47/48...
# Generated 11 propositions
# Processing chunk 48/48...
# Generated 13 propositions
#
# Evaluating proposition quality...
# Evaluating proposition 1/520...
# Proposition failed quality check: AI has been studied for centuries and is often dep...
# Proposition failed quality check: The formal field of AI research began in the mid -...
# Evaluating proposition 11/520...
# Proposition failed quality check: Recent breakthroughs in deep learning have revolut...
# Proposition failed quality check: Modern AI systems are increasingly prevalent in ev...
# Proposition failed quality check: Virtual assistants like Siri and Alexa are example...
# Proposition failed quality check: Recommendation algorithms on streaming services an...
# Proposition failed quality check: AI is impacting how people live, work, and interac...
# Proposition failed quality check: The development of self - driving cars is an examp...
# Proposition failed quality check: The development of advanced medical diagnostics is...
# Proposition failed quality check: Machine learning (ML) is a subset of AI....
# Evaluating proposition 21/520...
# Proposition failed quality check: ML algorithms identify patterns....
# Proposition failed quality check: ML algorithms make predictions....
# Proposition failed quality check: Input data is paired with the correct output....
# Proposition failed quality check: Pairing input data with correct output allows the ...
# Proposition failed quality check: Pairing input data with correct output allows the ...
# Evaluating proposition 31/520...
# Proposition failed quality check: Image classification is an example of using paired...
# Proposition failed quality check: Spam detection is an example of using paired input...
# Proposition failed quality check: Clustering is a common technique in unsupervised l...
# Proposition failed quality check: Clustering involves grouping similar data points i...
# Proposition failed quality check: Dimensionality reduction is a common technique in ...
# JSON generation ERROR!
# Proposition failed quality check: Reinforcement learning involves training an agent ...
# Evaluating proposition 41/520...
# Proposition failed quality check: The agent in reinforcement learning receives feedb...
# Proposition failed quality check: The approach of the agent learning through trial a...
# Proposition failed quality check: Convolutional Neural Networks (CNNs) are a type of...
# Evaluating proposition 51/520...
# Proposition failed quality check: Computer vision is a field of AI....
# Evaluating proposition 61/520...
# Proposition failed quality check: Image segmentation is a task in computer vision....
# Proposition failed quality check: Computer vision is used in self - driving cars....
# Proposition failed quality check: Computer vision is used in medical imaging....
# Proposition failed quality check: Computer vision is used in surveillance systems....
# Proposition failed quality check: The applications of AI are vast....
# Proposition failed quality check: The applications of AI continue to expand across v...
# Proposition failed quality check: AI is transforming healthcare....
# Proposition failed quality check: Medical diagnosis is an application of AI in healt...
# Proposition failed quality check: Drug discovery is an application of AI in healthca...
# Evaluating proposition 71/520...
# Proposition failed quality check: Personalized medicine is an application of AI in h...
# Proposition failed quality check: Robotic surgery is an application of AI in healthc...
# Proposition failed quality check: AI - powered tools can predict patient outcomes....
# Proposition failed quality check: AI - powered tools can assist in treatment plannin...
# Proposition failed quality check: AI-powered tools can predict patient outcomes....
# Proposition failed quality check: AI-powered tools can assist in treatment planning....
# Proposition failed quality check: In finance, AI is used for fraud detection....
# Proposition failed quality check: In finance, AI is used for algorithmic trading....
# Evaluating proposition 81/520...
# Proposition failed quality check: In finance, AI is used for risk management....
# Proposition failed quality check: In finance, AI is used for customer service....
# Proposition failed quality check: AI algorithms can analyze large datasets to identi...
# Proposition failed quality check: AI algorithms can predict market trends....
# Proposition failed quality check: AI is revolutionizing transportation with the deve...
# Proposition failed quality check: AI is revolutionizing transportation with traffic ...
# Proposition failed quality check: AI is revolutionizing transportation with logistic...
# Evaluating proposition 91/520...
# Proposition failed quality check: The retail industry uses AI for personalized recom...
# Proposition failed quality check: The retail industry uses AI for inventory manageme...
# Proposition failed quality check: The retail industry uses AI for customer service c...
# Proposition failed quality check: AI-powered systems can analyze customer data....
# Evaluating proposition 101/520...
# Evaluating proposition 111/520...
# Proposition failed quality check: The capabilities of AI have raised concerns about ...
# Proposition failed quality check: Establishing clear guidelines and ethical framewor...
# Evaluating proposition 121/520...
# Proposition failed quality check: The future of AI is likely to be chara (incomplete...
# Proposition failed quality check: Quantum computing has the potential to significant...
# JSON generation ERROR!
# Proposition failed quality check: Quantum computing enabling breakthroughs in areas ...
# Evaluating proposition 131/520...
# Proposition failed quality check: As AI becomes more pervasive, there will be a grow...
# Proposition failed quality check: Regulation and governance for AI includes establis...
# Proposition failed quality check: Regulation and governance for AI includes addressi...
# Proposition failed quality check: Regulation and governance for AI includes protecti...
# Evaluating proposition 141/520...
# Proposition failed quality check: International collaborations on standards for AI w...
# Proposition failed quality check: By understanding the core concepts, applications, ...
# Proposition failed quality check: Continued research for AI is essential for realizi...
# Proposition failed quality check: Responsible development for AI is essential for re...
# Proposition failed quality check: Thoughtful governance for AI is essential for real...
# Proposition failed quality check: The integration of AI and robotics combines the ph...
# Proposition failed quality check: The synergy of AI and robotics enables robots to p...
# Proposition failed quality check: The synergy of AI and robotics enables robots to a...
# Proposition failed quality check: The synergy of AI and robotics enables robots to i...
# Proposition failed quality check: AI - powered robots are used in manufacturing....
# Evaluating proposition 151/520...
# Proposition failed quality check: AI - powered robots are used in healthcare....
# Proposition failed quality check: AI - powered robots are used in logistics....
# Proposition failed quality check: AI - powered robots are used in exploration....
# Proposition failed quality check: Industrial robots are used in manufacturing for ta...
# Proposition failed quality check: Industrial robots are used in manufacturing for ta...
# Proposition failed quality check: Industrial robots are used in manufacturing for ta...
# Proposition failed quality check: Industrial robots are used in manufacturing for ta...
# Proposition failed quality check: AI enhances the precision of industrial robots....
# Proposition failed quality check: AI enhances the efficiency of industrial robots....
# Proposition failed quality check: AI enhances the adaptability of industrial robots....
# Evaluating proposition 161/520...
# Proposition failed quality check: AI allows industrial robots to work alongside huma...
# Proposition failed quality check: Service robots assist humans....
# Proposition failed quality check: Imitation learning allows robots to learn complex ...
# Evaluating proposition 171/520...
# Proposition failed quality check: SLAM is crucial for autonomous....
# Proposition failed quality check: AI in business operations leads to increased effic...
# Evaluating proposition 181/520...
# Proposition failed quality check: AI enhances CRM systems by providing personalized ...
# Proposition failed quality check: AI enhances CRM systems by predicting customer beh...
# Proposition failed quality check: AI enhances CRM systems by providing personalized ...
# Proposition failed quality check: AI enhances CRM systems by predicting customer beh...
# Proposition failed quality check: AI enhances CRM systems by automating customer ser...
# Proposition failed quality check: AI - powered chatbots improve customer engagement ...
# Proposition failed quality check: AI - powered recommendation engines improve custom...
# Proposition failed quality check: AI - powered sentiment analysis tools improve cust...
# Proposition failed quality check: AI optimizes supply chain operations by predicting...
# Proposition failed quality check: AI optimizes supply chain operations by managing i...
# Evaluating proposition 191/520...
# Proposition failed quality check: AI optimizes supply chain operations by streamlini...
# Proposition failed quality check: AI - powered systems improve supply chain forecast...
# Proposition failed quality check: AI - powered systems reduce waste in supply chain....
# Proposition failed quality check: AI - powered systems enhance supply chain resilien...
# Proposition failed quality check: AI is used in HR for talent acquisition....
# Proposition failed quality check: AI is used in HR for employee onboarding....
# Proposition failed quality check: AI is used in HR for performance management....
# Proposition failed quality check: AI is used in HR for training....
# Proposition failed quality check: AI - powered tools automate recruitment processes ...
# Proposition failed quality check: AI - powered tools personalize training programs i...
# Evaluating proposition 201/520...
# Proposition failed quality check: AI - powered tools provide insights into employee ...
# Proposition failed quality check: AI enhances marketing and sales....
# Proposition failed quality check: AI - powered tools improve targeting in marketing ...
# Proposition failed quality check: AI - powered tools optimize ad spending in marketi...
# Proposition failed quality check: AI - powered tools enhance customer segmentation i...
# Proposition failed quality check: AI is used in financial services for fraud detecti...
# Proposition failed quality check: AI is used in financial services for risk manageme...
# Proposition failed quality check: AI is used in financial services for algorithmic t...
# Evaluating proposition 211/520...
# Proposition failed quality check: AI - powered systems analyze large datasets in fin...
# Proposition failed quality check: AI - powered systems predict market movements in f...
# Proposition failed quality check: AI - powered systems automate financial processes ...
# Proposition failed quality check: The increasing capabilities of AI raise concerns a...
# Proposition failed quality check: Job displacement concerns are particularly in indu...
# Proposition failed quality check: AI may automate some jobs in industries with repet...
# Proposition failed quality check: AI creates new opportunities and transforms existi...
# Proposition failed quality check: Addressing the potential impacts of AI on the work...
# Proposition failed quality check: Reskilling and upskilling programs equip workers w...
# Proposition failed quality check: The future of work is likely to involve increased ...
# Evaluating proposition 221/520...
# Proposition failed quality check: The development and deployment of AI create new jo...
# Proposition failed quality check: The employment of AI creates new job roles in area...
# Proposition failed quality check: New job roles created by AI require specialized sk...
# Proposition failed quality check: AI is increasingly being used as a tool for creati...
# Proposition failed quality check: AI-powered systems can assist in design processes....
# Evaluating proposition 231/520...
# Proposition failed quality check: AI-powered systems can accelerate scientific disco...
# Proposition failed quality check: AI algorithms learn from something (not fully spec...
# Proposition failed quality check: AI systems learn from existing art and generate ne...
# Proposition failed quality check: AI-powered tools assist musicians in the creative ...
# Proposition failed quality check: AI-powered writing tools assist writers with resea...
# Proposition failed quality check: AI accelerates innovation by analyzing large datas...
# Proposition failed quality check: AI-powered tools are used in research....
# Evaluating proposition 241/520...
# Proposition failed quality check: AI - powered virtual tutors and learning assistant...
# Proposition failed quality check: AI - powered virtual tutors and learning assistant...
# Proposition failed quality check: AI - powered virtual tutors and learning assistant...
# Proposition failed quality check: AI - powered virtual tutors and learning assistant...
# Evaluating proposition 251/520...
# Proposition failed quality check: AI - powered virtual tutors and learning assistant...
# Proposition failed quality check: AI saves educators time in grading and feedback pr...
# Proposition failed quality check: AI provides timely feedback to students in grading...
# Proposition failed quality check: AI - powered systems can assess assignments....
# Proposition failed quality check: AI - powered systems can assess exams....
# Proposition failed quality check: AI - powered systems identify areas for improvemen...
# Proposition failed quality check: Educational data mining uses AI to analyze student...
# Proposition failed quality check: Educational data mining uses AI to identify patter...
# Evaluating proposition 261/520...
# Proposition failed quality check: Educational data mining uses AI to predict learnin...
# Proposition failed quality check: Information from educational data mining can impro...
# Proposition failed quality check: Information from educational data mining can enhan...
# Proposition failed quality check: AI - powered tools enhance accuracy, efficiency, a...
# Proposition failed quality check: Personalized medicine involves using individual pa...
# Evaluating proposition 271/520...
# Proposition failed quality check: Personalized medicine enhances treatment effective...
# Proposition failed quality check: Personalized medicine reduces adverse effects....
# Proposition failed quality check: AI - powered robotic surgery systems perform compl...
# Proposition failed quality check: AI - powered robotic surgery systems enhance dexte...
# Proposition failed quality check: AI - powered robotic surgery systems reduce invasi...
# Proposition failed quality check: AI - powered robotic surgery systems improve patie...
# Proposition failed quality check: AI streamlines healthcare administration....
# Proposition failed quality check: AI automates tasks in healthcare administration....
# Proposition failed quality check: AI manages patient records in healthcare administr...
# Evaluating proposition 281/520...
# Proposition failed quality check: AI optimizes workflows in healthcare administratio...
# Proposition failed quality check: AI - powered systems in healthcare administration ...
# Proposition failed quality check: AI - powered systems in healthcare administration ...
# Proposition failed quality check: AI - powered systems in healthcare administration ...
# Proposition failed quality check: AI enhances cybersecurity by detecting and prevent...
# Proposition failed quality check: AI analyzes network traffic for cybersecurity....
# Proposition failed quality check: AI identifies vulnerabilities for cybersecurity....
# Proposition failed quality check: Cybersecurity involves detecting and preventing th...
# Proposition failed quality check: AI - powered systems automate security tasks, impr...
# Evaluating proposition 291/520...
# Proposition failed quality check: AI - powered anomaly detection systems provide rea...
# Proposition failed quality check: AI - powered systems improve accuracy, reduce fals...
# Proposition failed quality check: AI helps manage vulnerabilities by identifying and...
# Proposition failed quality check: AI - powered tools reduce the risk of cyberattacks...
# Proposition failed quality check: AI - powered systems improve response time in inci...
# Proposition failed quality check: AI - powered systems minimize damage in incident r...
# Evaluating proposition 301/520...
# Proposition failed quality check: AI - powered systems enhance recovery efforts in i...
# Proposition failed quality check: AI - powered solutions can improve resource manage...
# Proposition failed quality check: AI - powered solutions can enhance decision - maki...
# Proposition failed quality check: There are disparities....
# Proposition failed quality check: AI - powered solutions can improve resource manage...
# Proposition failed quality check: AI - powered solutions can enhance decision - maki...
# Proposition failed quality check: AI - powered solutions can support sustainable dev...
# Proposition failed quality check: AI for social good projects focus on using AI to i...
# Evaluating proposition 311/520...
# Proposition failed quality check: AI for social good projects focus on using AI to i...
# Proposition failed quality check: AI for social good projects focus on using AI to i...
# Proposition failed quality check: AI for social good projects promote equity and wel...
# Proposition failed quality check: Promoting fairness in AI systems is part of addres...
# Proposition failed quality check: Promoting transparency in AI systems is part of ad...
# Proposition failed quality check: Protecting privacy and human rights is part of add...
# Proposition failed quality check: Public perception and trust in AI are essential fo...
# Evaluating proposition 321/520...
# Proposition failed quality check: Building trust in AI requires transparency....
# Proposition failed quality check: AI - powered smart transportation systems optimize...
# Proposition failed quality check: AI - powered smart transportation systems optimize...
# Proposition failed quality check: AI - powered smart transportation systems reduce c...
# Proposition failed quality check: AI - powered smart transportation systems enhance ...
# Evaluating proposition 331/520...
# Proposition failed quality check: AI - powered smart transportation systems use real...
# Proposition failed quality check: AI - powered smart transportation systems use real...
# Proposition failed quality check: AI - powered smart transportation systems use real...
# Proposition failed quality check: AI optimizes energy management in smart cities by ...
# Proposition failed quality check: AI optimizes energy management in smart cities by ...
# Proposition failed quality check: AI optimizes energy management in smart cities by ...
# Proposition failed quality check: AI - powered systems enhance grid stability....
# Proposition failed quality check: AI - powered systems reduce energy waste....
# Proposition failed quality check: AI - powered systems support the integration of re...
# Proposition failed quality check: AI enhances public safety and security in smart ci...
# Evaluating proposition 341/520...
# Proposition failed quality check: AI enhances public safety and security in smart ci...
# Proposition failed quality check: AI enhances public safety and security in smart ci...
# Proposition failed quality check: AI - powered systems improve crime prevention....
# Proposition failed quality check: AI - powered systems enhance situational awareness...
# Proposition failed quality check: AI - powered systems support rapid response....
# Proposition failed quality check: AI - powered systems improve crime prevention....
# Proposition failed quality check: AI - powered systems enhance situational awareness...
# Proposition failed quality check: AI - powered systems support rapid response to inc...
# Proposition failed quality check: AI - powered environmental monitoring systems trac...
# Proposition failed quality check: AI - powered environmental monitoring systems dete...
# Evaluating proposition 351/520...
# Proposition failed quality check: AI - powered environmental monitoring systems supp...
# Proposition failed quality check: AI - powered environmental monitoring systems prov...
# Proposition failed quality check: AI - powered environmental monitoring systems iden...
# Proposition failed quality check: AI - powered environmental monitoring systems info...
# Proposition failed quality check: Research in deep learning is focused on developing...
# Proposition failed quality check: Research in deep learning is focused on exploring ...
# Proposition failed quality check: Research in XAI focuses on developing methods for ...
# Evaluating proposition 361/520...
# Proposition failed quality check: Research in XAI focuses on enhancing trust....
# Proposition failed quality check: Research in XAI focuses on improving accountabilit...
# Proposition failed quality check: Understanding the human brain can inspire new AI a...
# Proposition failed quality check: AI can provide insights into brain function and co...
# Proposition failed quality check: Mitigating risks is part of ensuring AI safety and...
# Proposition failed quality check: Preventing unintended consequences is part of ensu...
# Evaluating proposition 371/520...
# Proposition failed quality check: Human - centered AI focuses on developing AI syste...
# Proposition failed quality check: Human - centered AI focuses on developing AI syste...
# Proposition failed quality check: Human - centered AI focuses on developing AI syste...
# Proposition failed quality check: Developing and deploying human - centered AI invol...
# Proposition failed quality check: Developing and deploying human - centered AI invol...
# Proposition failed quality check: Developing and deploying human - centered AI invol...
# Proposition failed quality check: Generative AI models such as Generative Adversaria...
# Proposition failed quality check: Generative AI models such as transformers are capa...
# Proposition failed quality check: Generative AI models such as GANs and transformers...
# Proposition failed quality check: Generative AI models such as GANs and transformers...
# Evaluating proposition 381/520...
# Proposition failed quality check: Generative AI models are pushing the boundaries of...
# Proposition failed quality check: Generative AI models are opening up new possibilit...
# Proposition failed quality check: AI is increasingly used as a collaborative partner...
# Proposition failed quality check: AI is increasingly used as a collaborative partner...
# Proposition failed quality check: AI tools can assist artists and designers with ide...
# Proposition failed quality check: AI tools can assist artists and designers with pro...
# Proposition failed quality check: AI tools can assist artists and designers with ref...
# Proposition failed quality check: AI is transforming music and sound design by enabl...
# Evaluating proposition 391/520...
# Proposition failed quality check: AI - powered tools can create interactive musical ...
# Proposition failed quality check: AI - powered tools can assist with audio mixing an...
# Proposition failed quality check: AI - powered tools can create realistic images in ...
# Proposition failed quality check: AI - powered tools can generate design variations ...
# Proposition failed quality check: AI - powered tools can automate repetitive tasks i...
# Proposition failed quality check: AI is enhancing interactive media....
# Evaluating proposition 401/520...
# Proposition failed quality check: AI - powered systems analyze data, predict climate...
# Proposition failed quality check: AI - powered tools improve farming practices in ag...
# Proposition failed quality check: AI - powered tools reduce environmental impact in ...
# Proposition failed quality check: AI - powered tools enhance food security in agricu...
# Proposition failed quality check: AI is used in wildlife conservation to monitor pop...
# Proposition failed quality check: AI is used in wildlife conservation to track movem...
# Evaluating proposition 411/520...
# Proposition failed quality check: AI - powered environmental monitoring systems trac...
# Proposition failed quality check: AI - powered environmental monitoring systems trac...
# Proposition failed quality check: AI - powered environmental monitoring systems dete...
# Proposition failed quality check: AI - powered environmental monitoring systems supp...
# Proposition failed quality check: AI - powered environmental monitoring systems prov...
# Proposition failed quality check: AI - powered environmental monitoring systems iden...
# Proposition failed quality check: AI - powered environmental monitoring systems info...
# Proposition failed quality check: AI enhances disaster response by analyzing data....
# Proposition failed quality check: AI enhances disaster response by predicting impact...
# Evaluating proposition 421/520...
# Proposition failed quality check: AI - powered systems improve situational awareness...
# Proposition failed quality check: AI - powered systems optimize resource allocation....
# Proposition failed quality check: AI - powered systems enhance coordination among re...
# Proposition failed quality check: AI strategy and policy frameworks promote innovati...
# Proposition failed quality check: AI strategy and policy frameworks ensure responsib...
# Evaluating proposition 431/520...
# Proposition failed quality check: Governments play a crucial role in funding AI rese...
# Proposition failed quality check: Government investments drive innovation and foster...
# Proposition failed quality check: Engaging the public in discussions about AI is cru...
# Proposition failed quality check: Engaging the public in discussions about AI is cru...
# Proposition failed quality check: Education and awareness campaigns inform the publi...
# Proposition failed quality check: Education and awareness campaigns inform the publi...
# Evaluating proposition 441/520...
# Proposition failed quality check: Education and awareness campaigns inform the publi...
# Proposition failed quality check: Ethical AI principles guide the development of AI ...
# Proposition failed quality check: Ethical AI principles guide the deployment of AI s...
# Proposition failed quality check: Ethical AI principles ensure AI systems are fair....
# Proposition failed quality check: Ethical AI principles ensure AI systems are transp...
# Proposition failed quality check: Ethical AI principles ensure AI systems are accoun...
# Proposition failed quality check: Ethical AI principles ensure AI systems are benefi...
# Proposition failed quality check: Key ethical AI principles include respect for huma...
# Proposition failed quality check: Key ethical AI principles include privacy....
# Proposition failed quality check: Key ethical AI principles include non - discrimina...
# Evaluating proposition 451/520...
# Proposition failed quality check: Key ethical AI principles include beneficence....
# Proposition failed quality check: Inheriting and amplifying biases in AI systems lea...
# Proposition failed quality check: Inheriting and amplifying biases in AI systems lea...
# Proposition failed quality check: Addressing bias in AI requires careful data collec...
# Proposition failed quality check: Addressing bias in AI requires careful algorithm d...
# Proposition failed quality check: Addressing bias in AI requires ongoing monitoring ...
# Proposition failed quality check: Building trust in AI systems requires transparency...
# Proposition failed quality check: Explainable AI (XAI) techniques aim to make AI dec...
# Evaluating proposition 461/520...
# Proposition failed quality check: Making AI decisions more understandable enables us...
# Proposition failed quality check: Relying on large amounts of data raises concerns a...
# Proposition failed quality check: Ensuring responsible data handling is crucial....
# Proposition failed quality check: Implementing privacy - preserving techniques is cr...
# Proposition failed quality check: Complying with data protection regulations is cruc...
# Proposition failed quality check: Establishing accountability and responsibility for...
# Proposition failed quality check: Establishing accountability and responsibility for...
# Proposition failed quality check: Addressing potential harms and ensuring ethical be...
# Proposition failed quality check: Defining roles and responsibilities for developers...
# Evaluating proposition 471/520...
# Proposition failed quality check: Ensuring that AI systems are robust and reliable i...
# Proposition failed quality check: Empowering users with control over AI systems is i...
# Proposition failed quality check: Empowering users with control over AI systems and ...
# Proposition failed quality check: Incorporating ethical considerations into the desi...
# Evaluating proposition 481/520...
# Proposition failed quality check: Public awareness campaigns, educational initiative...
# Proposition failed quality check: Implications helps build trust....
# Proposition failed quality check: Public awareness campaigns foster informed underst...
# Proposition failed quality check: Educational initiatives foster informed understand...
# Proposition failed quality check: Open dialogue fosters informed understanding and a...
# Proposition failed quality check: Continued research and innovation are essential fo...
# Proposition failed quality check: Continued research and innovation are essential fo...
# Proposition failed quality check: Continued research and innovation are essential fo...
# Proposition failed quality check: Advancing AI capabilities includes investing in ba...
# Proposition failed quality check: Advancing AI capabilities includes investing in ap...
# Evaluating proposition 491/520...
# Proposition failed quality check: Advancing AI capabilities includes developing new ...
# Proposition failed quality check: Responsible development and deployment of AI are c...
# Proposition failed quality check: Responsible development and deployment of AI are c...
# Proposition failed quality check: Responsible development and deployment of AI invol...
# Proposition failed quality check: Responsible development and deployment of AI invol...
# Proposition failed quality check: Global collaboration and cooperation for AI includ...
# Proposition failed quality check: Global collaboration and cooperation for AI includ...
# Proposition failed quality check: Global collaboration and cooperation for AI includ...
# Evaluating proposition 501/520...
# Proposition failed quality check: Preparing the workforce for the future of AI requi...
# Proposition failed quality check: Education and training initiatives for the future ...
# Proposition failed quality check: Education and training initiatives for the future ...
# Proposition failed quality check: Preparing the workforce for the future of AI inclu...
# Proposition failed quality check: Preparing the workforce for the future of AI inclu...
# Proposition failed quality check: Preparing the workforce for the future of AI inclu...
# Proposition failed quality check: A human-centered approach to AI focuses on develop...
# Proposition failed quality check: A human - centered approach to AI focuses on devel...
# Proposition failed quality check: A human - centered approach to AI focuses on devel...
# Proposition failed quality check: A human - centered approach to AI focuses on devel...
# Evaluating proposition 511/520...
# Proposition failed quality check: A human - centered approach to AI involves conside...
# Proposition failed quality check: A human - centered approach to AI involves conside...
# Proposition failed quality check: A human - centered approach to AI involves conside...
# Proposition failed quality check: By embracing principles and working together, we c...
# Proposition failed quality check: By embracing principles and working together, we c...
# Proposition failed quality check: By embracing principles and working together, we c...
# Proposition failed quality check: The path forward requires dedication....
# Proposition failed quality check: The path forward requires collaboration....
#
# Retained 172/520 propositions after quality filtering
# Creating embeddings for 48 chunks...
# Creating embeddings for 172 propositions...
#
#
# === Testing Query 1/1 ===
# Query: What are the main ethical concerns in AI development?
#
# === Query: What are the main ethical concerns in AI development? ===
#
# Retrieving with proposition-based approach...
# Retrieving with chunk-based approach...
#
# === Proposition-Based Results ===
# 1) The rapid development and deployment of AI raise significant ethical and societal concerns. (Score: 0.9325)
# 2) Addressing the ethical implications of AI in the workplace is crucial. (Score: 0.9318)
# 3) Addressing the ethical implications of AI is crucial for ensuring its positive social impact. (Score: 0.9228)
# 4) The path forward requires a commitment to responsible AI development and deployment. (Score: 0.8998)
# 5) Transparency and explainability are key to building trust in AI. (Score: 0.8959)
#
# === Chunk-Based Results ===
# 1) s issues such as bias, transparency, privacy, and safety. Balancing innovation with ethical
# considerations is a key challenge.
# Funding for AI Resear... (Score: 0.8261)
# 2) good initiatives aim to leverage AI for
# positive impact.
# Regulation and Governance
# As AI becomes more pervasive, there will be a growing need for r... (Score: 0.8228)
# 3) es.
# User Control and Agency
# Empowering users with control over AI systems and providing them with agency in their
# interactions with AI enhances tru... (Score: 0.8168)
# 4) are disparities. AI-powered solutions can improve resource management, enhance
# decision-making, and support sustainable development.
# AI for Social G... (Score: 0.8141)
# 5) ities of AI have raised concerns about job displacement, particularly in
# industries with repetitive or routine tasks. Addressing the potential econom... (Score: 0.8124)
#
# Generating response from proposition-based results...
# Generating response from chunk-based results...
#
# Evaluating responses...
#
# === Proposition-Based Response ===
# The main ethical concerns in AI development include the need to address its ethical implications in the workplace and for ensuring positive social impact. Transparency and explainability are also key as they help build trust in AI. Additionally, a commitment to responsible AI development and deployment is required. Overall, the rapid development and deployment of AI raise significant ethical and societal concerns.
#
# === Chunk-Based Response ===
# The main ethical concerns in AI development include:
# - Bias and fairness: Ensuring that AI systems do not discriminate against certain groups.
# - Transparency: Making AI decision-making processes understandable.
# - Privacy: Protecting individuals' data from unauthorized access and use.
# - Safety: Minimizing the risk of harm caused by AI systems.
# - Autonomy and control: Establishing guidelines for AI systems' increasing autonomy and accountability.
# - Weaponization of AI: Addressing the ethical and security concerns associated with AI in autonomous weapons systems.
# - Job displacement: Considering the potential economic and social impacts of AI-driven automation.
# - Public perception and trust: Building trust through transparency, user control, and education.
#
# Balancing innovation with these ethical considerations is a key challenge in AI development. Additionally, as AI becomes more pervasive, there is a growing need for regulation and governance to ensure responsible development and deployment, including establishing ethical guidelines and international collaborations on standards.
#
# === Evaluation ===
# **1. Accuracy**
#    - **Proposition - Based Retrieval**:
#      - **Strengths**: It mentions some valid ethical concerns such as transparency, explainability, and responsible development. These are indeed important aspects in the realm of AI ethics.
#      - **Weaknesses**: It lacks several key concerns that are widely recognized in the reference answer. For example, it does not mention bias and fairness, privacy, safety, or the potential for misuse.
#    - **Chunk - Based Retrieval**:
#      - **Strengths**: It comprehensively lists a wide range of ethical concerns including bias and fairness, privacy, safety, and many others that are in line with the reference answer. This makes it more accurate in terms of covering the main ethical concerns in AI development.
#      - **Weaknesses**: It goes into more detail about some aspects like job displacement and weaponization of AI which might not be considered as central to the "main" ethical concerns compared to others. However, overall, it still provides a more accurate set of concerns.
#
# **2. Relevance**
#    - **Proposition - Based Retrieval**:
#      - **Strengths**: It is relevant as it touches on important ethical aspects related to AI development, such as workplace implications, social impact, and transparency.
#      - **Weaknesses**: It does not directly address all the main ethical concerns in a comprehensive way. For example, it does not mention the more technical and fundamental concerns like bias, privacy, and safety which are highly relevant to the query.
#    - **Chunk - Based Retrieval**:
#      - **Strengths**: It is highly relevant as it directly lists all the main ethical concerns in AI development. Each point clearly relates to the query about what the main ethical concerns are.
#      - **Weaknesses**: Some of the points could be argued to be more tangential than others in terms of being "main" concerns. For example, job displacement is more of an indirect consequence of AI development compared to bias, privacy, etc.
#
# **3. Conciseness**
#    - **Proposition - Based Retrieval**:
#      - **Strengths**: It is relatively concise, presenting the main ideas in a short paragraph without going into excessive detail.
#      - **Weaknesses**: In its conciseness, it fails to cover all the main ethical concerns, so it is not as complete as it could be while being concise.
#    - **Chunk - Based Retrieval**:
#      - **Strengths**: It manages to list multiple main ethical concerns in a relatively organized way without being overly wordy. It provides a good balance between comprehensiveness and conciseness.
#      - **Weaknesses**: It could potentially be made more concise by combining some related points or trimming down the explanations for each concern. However, overall, it is still a relatively concise way of presenting a lot of information.
#
# **4. Clarity**
#    - **Proposition - Based Retrieval**:
#      - **Strengths**: The language is straightforward and easy to understand. It clearly conveys the general idea of ethical concerns in AI development.
#      - **Weaknesses**: Since it does not list the concerns explicitly, it may not be as clear for someone looking for a detailed breakdown of the main ethical concerns.
#    - **Chunk - Based Retrieval**:
#      - **Strengths**: It is very clear as it lists the concerns in a numbered format, making it easy to read and understand each individual concern.
#      - **Weaknesses**: The explanations for each concern could potentially be more in - depth for better clarity, especially for those who are not familiar with the concepts.
#
# **Overall, the chunk - based retrieval approach performed better**:
#  - It was more accurate as it covered a wider range of the main ethical concerns compared to the proposition - based retrieval.
#  - It was more relevant as it directly addressed all the main concerns in the query.
#  - It achieved a good balance between conciseness and comprehensiveness.
#  - It was also clearer due to its organized list format. The proposition - based retrieval had some strengths in terms of conciseness and clarity of general ideas, but its weaknesses in accuracy and relevance made it less effective for this particular query.
#
#
# === Generating Overall Analysis ===
#
# **1. When proposition - based retrieval performs better**
#
#    - **Strengths**:
#      - **Conceptual Clarity**: Proposition - based retrieval is good at extracting and presenting high - level concepts directly related to the query. In the given example for the query "What are the main ethical concerns in AI development", it was able to quickly identify and mention valid ethical concerns like transparency, explainability, and responsible development. This shows that it can efficiently capture the key ideas relevant to the query, providing a more focused and conceptually clear response.
#      - **Semantic Understanding**: It seems to have a relatively good semantic understanding of the query. By identifying the relevant propositions related to AI development and ethics, it can zero in on the important aspects. For example, it doesn't get distracted by less relevant details and instead focuses on the core ethical concepts associated with the field.
#
#    - **Weaknesses**:
#      - **Lack of Contextual Richness**: Proposition - based retrieval may not provide detailed context around the propositions. Just listing the ethical concerns like transparency and explainability doesn't give much background information on why these are important in AI development, how they are related to each other, or real - world examples of their implications.
#      - **Limited Coverage**: There could be a risk of missing out on some ethical concerns that are not as straightforwardly captured by the initial set of propositions. For instance, it might not consider more niche or emerging ethical issues that are not immediately obvious from the basic understanding of AI development ethics.
#
# **2. When chunk - based retrieval performs better**
#
#    - **Strengths**:
#      - **Contextual Completeness**: Chunk - based retrieval can provide more context - rich information. It can retrieve larger chunks of text that contain not only the relevant concepts but also the surrounding details, explanations, and examples. For the AI ethics query, it could retrieve chunks that discuss how transparency is achieved in AI algorithms, real - life cases where explainability in AI has been a problem, and how responsible development is implemented in different organizations.
#      - **Flexibility in Representation**: Chunks can be more flexible in representing information. They can include different types of content such as narratives, case studies, and expert opinions. This allows for a more comprehensive and multi - faceted response. For example, a chunk could contain a story about an AI system that caused harm due to lack of transparency, which would be very useful in answering the query about ethical concerns.
#    - **Weaknesses**:
#      - **Inefficient for Simple Queries**: For very simple queries like the one in the example, chunk - based retrieval might be overkill. Retrieving large chunks of text when a simple list of concepts would suffice can be wasteful in terms of processing time and may introduce noise. The extra information in the chunks might not be relevant to the specific query and could make it harder to quickly extract the key information.
#      - **Risk of Information Overload**: There is a higher risk of information overload with chunk - based retrieval. If not carefully filtered, the retrieved chunks could contain a lot of extraneous information that makes it difficult to distill the most relevant answers to the query.
#
# **3. Overall strengths and weaknesses of each approach**
#
#    - **Proposition - Based Retrieval**
#      - **Strengths**:
#        - Quick identification of key concepts.
#        - Good semantic understanding for focused queries.
#      - **Weaknesses**:
#        - Lack of detailed context.
#        - Limited coverage of all relevant aspects.
#    - **Chunk - Based Retrieval**
#      - **Strengths**:
#        - Rich contextual information.
#        - Flexibility in representing different types of content.
#      - **Weaknesses**:
#        - Inefficient for simple queries.
#        - Risk of information overload.
#
# **4. Recommendations for when to use each approach**
#
#    - **Proposition - Based Retrieval**:
#      - Use when the query is very focused on high - level concepts and a quick, concise list of relevant ideas is needed. For example, in academic research when quickly identifying the main theories or concepts related to a topic. In a business setting, when looking for a summary of key issues like the main risks in a new market.
#    - **Chunk - Based Retrieval**:
#      - Use when a more in - depth, context - rich understanding is required. This is useful for tasks like writing detailed reports, providing comprehensive answers to complex questions, or when the user needs to understand the background, implications, and real - world examples related to a query. For instance, when creating a whitepaper on a technical topic or answering a legal query that requires precedents and detailed explanations.
#
#
# === Overall Analysis ===
# **1. When proposition - based retrieval performs better**
#
#    - **Strengths**:
#      - **Conceptual Clarity**: Proposition - based retrieval is good at extracting and presenting high - level concepts directly related to the query. In the given example for the query "What are the main ethical concerns in AI development", it was able to quickly identify and mention valid ethical concerns like transparency, explainability, and responsible development. This shows that it can efficiently capture the key ideas relevant to the query, providing a more focused and conceptually clear response.
#      - **Semantic Understanding**: It seems to have a relatively good semantic understanding of the query. By identifying the relevant propositions related to AI development and ethics, it can zero in on the important aspects. For example, it doesn't get distracted by less relevant details and instead focuses on the core ethical concepts associated with the field.
#
#    - **Weaknesses**:
#      - **Lack of Contextual Richness**: Proposition - based retrieval may not provide detailed context around the propositions. Just listing the ethical concerns like transparency and explainability doesn't give much background information on why these are important in AI development, how they are related to each other, or real - world examples of their implications.
#      - **Limited Coverage**: There could be a risk of missing out on some ethical concerns that are not as straightforwardly captured by the initial set of propositions. For instance, it might not consider more niche or emerging ethical issues that are not immediately obvious from the basic understanding of AI development ethics.
#
# **2. When chunk - based retrieval performs better**
#
#    - **Strengths**:
#      - **Contextual Completeness**: Chunk - based retrieval can provide more context - rich information. It can retrieve larger chunks of text that contain not only the relevant concepts but also the surrounding details, explanations, and examples. For the AI ethics query, it could retrieve chunks that discuss how transparency is achieved in AI algorithms, real - life cases where explainability in AI has been a problem, and how responsible development is implemented in different organizations.
#      - **Flexibility in Representation**: Chunks can be more flexible in representing information. They can include different types of content such as narratives, case studies, and expert opinions. This allows for a more comprehensive and multi - faceted response. For example, a chunk could contain a story about an AI system that caused harm due to lack of transparency, which would be very useful in answering the query about ethical concerns.
#    - **Weaknesses**:
#      - **Inefficient for Simple Queries**: For very simple queries like the one in the example, chunk - based retrieval might be overkill. Retrieving large chunks of text when a simple list of concepts would suffice can be wasteful in terms of processing time and may introduce noise. The extra information in the chunks might not be relevant to the specific query and could make it harder to quickly extract the key information.
#      - **Risk of Information Overload**: There is a higher risk of information overload with chunk - based retrieval. If not carefully filtered, the retrieved chunks could contain a lot of extraneous information that makes it difficult to distill the most relevant answers to the query.
#
# **3. Overall strengths and weaknesses of each approach**
#
#    - **Proposition - Based Retrieval**
#      - **Strengths**:
#        - Quick identification of key concepts.
#        - Good semantic understanding for focused queries.
#      - **Weaknesses**:
#        - Lack of detailed context.
#        - Limited coverage of all relevant aspects.
#    - **Chunk - Based Retrieval**
#      - **Strengths**:
#        - Rich contextual information.
#        - Flexibility in representing different types of content.
#      - **Weaknesses**:
#        - Inefficient for simple queries.
#        - Risk of information overload.
#
# **4. Recommendations for when to use each approach**
#
#    - **Proposition - Based Retrieval**:
#      - Use when the query is very focused on high - level concepts and a quick, concise list of relevant ideas is needed. For example, in academic research when quickly identifying the main theories or concepts related to a topic. In a business setting, when looking for a summary of key issues like the main risks in a new market.
#    - **Chunk - Based Retrieval**:
#      - Use when a more in - depth, context - rich understanding is required. This is useful for tasks like writing detailed reports, providing comprehensive answers to complex questions, or when the user needs to understand the background, implications, and real - world examples related to a query. For instance, when creating a whitepaper on a technical topic or answering a legal query that requires precedents and detailed explanations.
